# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
address = "Data Set/Northwind.xls"
excel_file = pd.ExcelFile(address)
excel_file.sheet_names
# Out:
# ['Categories',
#  'Customers',
#  'Employees',
#  'Orders Details',
#  'Orders',
#  'Product',
#  'Shippers',
#  'Suppliers']

# %%
data_frame = excel_file.parse("Product")
#head() returns top 5
data_frame.head()

#data_frame
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True

# %%
grouped_df = data_frame.groupby(data_frame['SupplierID'])
grouped_df.mean()
# Out:
#             ProductID  CategoryID   UnitPrice  UnitsInStock  UnitsOnOrder  \
# SupplierID
# 1            2.000000    1.333333   15.666667     23.000000     36.666667
# 2           35.000000    2.000000   20.350000     33.250000     25.000000
# 3            7.000000    3.666667   31.666667     47.000000      0.000000
# 4           31.000000    7.000000   46.000000     21.333333      6.666667
# 5           11.500000    4.000000   29.500000     54.000000     15.000000
# 6           14.000000    5.666667   14.916667     32.666667      0.000000
# 7           36.800000    4.000000   35.570000     22.000000      2.000000
# 8           32.000000    3.000000   28.175000     18.500000     12.500000
# 9           22.500000    5.000000   15.000000     82.500000      0.000000
# 10          24.000000    1.000000    4.500000     20.000000      0.000000
# 11          26.000000    3.000000   29.710000     46.666667      0.000000
# ...
